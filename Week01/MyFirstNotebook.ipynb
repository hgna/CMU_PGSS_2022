# %% [markdown]
# # first notebook

# %%
# read the csv file iris.csv
import pandas as pd

df = pd.read_csv("/content/drive/MyDrive/PGSS2022_Student/PGSS2022/L1--6-28-2022/iris.csv")

df.columns=['Sepal.Length', 'Sepal.Width', 'Petal.Length', 'Petal.Width', 'Class']
df #stands for directory file

# %%
! pwd
# Out:
# /content

# %%
! top
# Out:
# =top - 19:29:19 up 16 min,  0 users,  load average: 0.12, 0.19, 0.20
# Tasks:  19 total,   1 running,  17 sleeping,   0 stopped,   1 zombie
# %Cpu(s): 10.0 us,  2.0 sy,  0.0 ni, 87.1 id,  0.8 wa,  0.0 hi,  0.1 si,  0.0 st
# KiB Mem : 13298572 total, 10034888 free,  1095768 used,  2167916 buff/cache
# KiB Swap:        0 total,        0 free,        0 used. 12023244 avail Mem
#
#     PID USER      PR  NI    VIRT    RES    SHR S  %CPU %MEM     TIME+ COMMAND
#      98 root      20   0  924916 505972  31476 S 162.5  3.8   2:12.63 node
#      61 root      20   0  621864 168780  54656 S   6.2  1.3   0:08.45 python3
#       1 root      20   0     992      4      0 S   0.0  0.0   0:00.59 docker-i+
#       7 root      20   0  344864  55800  32816 S   0.0  0.4   0:02.77 node
#      18 root      20   0   35892   4844   3736 S   0.0  0.0   0:00.61 tail
#      29 root      20   0       0      0      0 Z   0.0  0.0   0:05.73 python3
#      30 root      20   0  156136  41128  12744 S   0.0  0.3   0:00.98 colab-fi+
#      43 root      20   0  199296  60712  15280 S   0.0  0.5   0:02.89 jupyter-+
#      44 root      20   0  715340   5788   4216 S   0.0  0.0   0:00.18 dap_mult+
#      81 root      20   0  127184  15404   6092 S   0.0  0.1   0:00.07 python3
#     132 root      20   0   18380   1500   1200 S   0.0  0.0   0:00.00 bash
#     133 root      20   0 2194000  23716  19172 S   0.0  0.2   0:00.04 drive
#     134 root      20   0   11464   1024    924 S   0.0  0.0   0:00.00 grep
#     196 root      20   0 2654844  53480  35868 S   0.0  0.4   0:00.90 drive
#     268 root      20   0   18380   3060   2812 S   0.0  0.0   0:00.00 bash
#     269 root      20   0  712304   4424   2168 S   0.0  0.0   0:00.05 director+
#     270 root      20   0    4572    876    816 S   0.0  0.0   0:00.04 tail      top - 19:29:22 up 16 min,  0 users,  load average: 0.12, 0.19, 0.20
# Tasks:  19 total,   1 running,  17 sleeping,   0 stopped,   1 zombie
# %Cpu(s): 41.6 us,  2.2 sy,  0.0 ni, 55.9 id,  0.0 wa,  0.0 hi,  0.3 si,  0.0 st
# KiB Mem : 13298572 total, 10013248 free,  1117284 used,  2168040 buff/cache
# KiB Swap:        0 total,        0 free,        0 used. 12001944 avail Mem
#
#
#      98 root      20   0  927580 525464  31476 S  78.7  4.0   2:14.99 node
#      61 root      20   0  621864 168780  54656 S   1.0  1.3   0:08.48 python3
#      81 root      20   0  127184  15404   6092 S   1.0  0.1   0:00.10 python3
#     196 root      20   0 2654844  53480  35868 S   1.0  0.4   0:00.93 drive
#       7 root      20   0  344864  56060  32816 S   0.7  0.4   0:02.79 node
#      43 root      20   0  199296  60716  15280 S   0.7  0.5   0:02.91 jupyter-+
#       1 root      20   0     992      4      0 S   0.0  0.0   0:00.59 docker-i+
#      18 root      20   0   35892   4844   3736 S   0.0  0.0   0:00.61 tail
#      29 root      20   0       0      0      0 Z   0.0  0.0   0:05.73 python3
#      30 root      20   0  156136  41128  12744 S   0.0  0.3   0:00.98 colab-fi+
#      44 root      20   0  715340   6496   4220 S   0.0  0.0   0:00.18 dap_mult+
#     132 root      20   0   18380   1500   1200 S   0.0  0.0   0:00.00 bash
#     133 root      20   0 2194000  23716  19172 S   0.0  0.2   0:00.04 drive
#     134 root      20   0   11464   1024    924 S   0.0  0.0   0:00.00 grep
#
#
# >
